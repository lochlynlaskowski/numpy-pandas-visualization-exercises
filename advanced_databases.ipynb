# %%
from env import get_db_url
import pandas as pd


url = get_db_url("employees")

# %%
# Read the employees and titles tables into two separate DataFrames.

sql = '''
SELECT * FROM employees
'''
employees = pd.read_sql(sql, url)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
sql = '''
SELECT * FROM titles
'''
titles = pd.read_sql(sql, url)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
# How many rows and columns do you have in each DataFrame? Is that what you expected?

employees.shape
# Out:
# (300024, 6)

# %%
titles.shape
# Out:
# (443308, 4)

# %%
# Display the summary statistics for each DataFrame.

employees.describe(), titles.describe(include = 'all')
# Out:
# (              emp_no
#  count  300024.000000
#  mean   253321.763392
#  std    161828.235540
#  min     10001.000000
#  25%     85006.750000
#  50%    249987.500000
#  75%    424993.250000
#  max    499999.000000,
#                 emp_no     title   from_date     to_date
#  count   443308.000000    443308      443308      443308
#  unique            NaN         7        6393        5888
#  top               NaN  Engineer  1998-10-25  9999-01-01
#  freq              NaN    115003         132      240124
#  mean    253075.034430       NaN         NaN         NaN
#  std     161853.292613       NaN         NaN         NaN
#  min      10001.000000       NaN         NaN         NaN
#  25%      84855.750000       NaN         NaN         NaN
#  50%     249847.500000       NaN         NaN         NaN
#  75%     424891.250000       NaN         NaN         NaN
#  max     499999.000000       NaN         NaN         NaN)

# %%
# How many unique titles are in the titles DataFrame? 7

# %%
# What is the oldest date in the to_date column? 1998-10-25

# %%
# What is the most recent date in the to_date column? 9999-01-01

# %%
# Copy the users and roles DataFrames from the examples above.
# Create the users DataFrame.
import numpy as np

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
# What is the result of using a right join on the DataFrames?


users.merge(roles, how='right', on=None, left_on='role_id', right_on='id', left_index=False, right_index=False, indicator=False)
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %%
# What is the result of using an outer join on the DataFrames?
joined = users.merge(roles, how='outer', on=None, left_on='role_id', right_on='id', left_index=False, right_index=False, indicator=False)
joined
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
# What happens if you drop the foreign keys from the DataFrames and try to merge them?
joined.drop(columns='id_x')
joined.drop(columns='id_y')
joined
# ###########
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %%
# Load the mpg dataset from PyDataset.

# Output and read the documentation for the mpg dataset.

from pydataset import data
data('mpg', show_doc = True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg = data('mpg')

# %%
# How many rows and columns are in the dataset?
mpg.shape
# Out:
# (234, 11)

# %%
# Check out your column names and perform any cleanup you may want on them.
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
# Display the summary statistics for the dataset.
mpg.describe(include = 'all')

# How many different manufacturers are there?
# -- 15

# How many different models are there?
# -- 38
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl class
# count        234  234  234.000000  234.000000  234   234
# ...

# %%
# Create a column named mileage_difference like you did in the DataFrames exercises; this column 
# should contain the difference between highway and city mileage for each car.

mpg['mileage_difference'] = (mpg.hwy - mpg.cty)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %%
# Create a column named average_mileage like you did in the DataFrames exercises; this is the mean 
# of the city and highway mileage.

mpg['average_mileage'] = (mpg.cty + mpg.hwy)/2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %%
# Create a new column on the mpg dataset named is_automatic that holds boolean values denoting
# whether the car has an automatic transmission.

mpg['is_automatic'] = mpg.trans.str.startswith('a')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# ...

# %%
# Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?
mpg.groupby('manufacturer').average_mileage.max().sort_values(ascending=False).head(1)
# Out:
# manufacturer
# volkswagen    39.5
# Name: average_mileage, dtype: float64

# %%
# Do automatic or manual cars have better miles per gallon? --manual cars have better average gas mileage
mpg.groupby('is_automatic').average_mileage.agg(['mean'])
# Out:
#                    mean
# is_automatic
# False         22.227273
# True          19.130573

# %%
# Use your get_db_url function to help you explore the data from the chipotle database.

url = get_db_url("chipotle")

# %%
sql = '''
SELECT * FROM orders
'''
orders = pd.read_sql(sql, url)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
orders.shape, orders.info(), orders.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
#  6   total_price         4622 non-null   float64
#  7   item_price_float    4622 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 289.0+ KB
# ((4622, 8),
#  None,
#                  id     order_id     quantity  total_price  item_price_float
#  count  4622.000000  4622.000000  4622.000000  4622.000000       4622.000000
#  mean   2311.500000   927.254868     1.075725     8.489186          7.464336
# ...

# %%
orders.dtypes
orders['item_price_float'] = orders.item_price.str.strip('$').astype('float')
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
# What is the total price for each order?
orders['total_price'] = (orders.quantity * orders.item_price_float)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
orders.groupby('order_id').total_price.sum()
# Out:
# order_id
# 1       11.56
# 2       33.96
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: total_price, Length: 1834, dtype: float64

# %%
# What are the most popular 3 items?
orders.groupby('item_name').item_name.count().sort_values(ascending=False).head(3)
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: item_name, dtype: int64

# %%
# Which item has produced the most revenue?
orders.groupby('item_name').total_price.sum().sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    8044.63
# Name: total_price, dtype: float64

# %%
# Join the employees and titles DataFrames together.
employees, titles
# Out:
# (        emp_no  birth_date first_name last_name gender   hire_date
#  0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
#  1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
#  2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
#  3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
#  4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
#  ...        ...         ...        ...       ...    ...         ...
#  300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
#  300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
#  300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
#  300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
#  300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#  [300024 rows x 6 columns],
#          emp_no            title   from_date     to_date
#  0        10001  Senior Engineer  1986-06-26  9999-01-01
# ...

# %%
employees_titles = employees.merge(titles, how='outer', on=None, left_on='emp_no', right_on='emp_no', left_index=False, right_index=False, indicator=True)
employees_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date _merge
# 0       Senior Engineer  1986-06-26  9999-01-01   both
# ...

# %%
# For each title, find the hire date of the employee that was hired most recently with that title.
employees_titles.groupby('title').from_date.max()
# Out:
# title
# Assistant Engineer    2000-02-01
# Engineer              2002-08-01
# Manager               1996-08-30
# Senior Engineer       2002-08-01
# Senior Staff          2002-08-01
# Staff                 2000-02-01
# Technique Leader      2000-02-01
# Name: from_date, dtype: object

# %%
# Write the code necessary to create a cross tabulation of the number of titles by department.
# (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code 
# to perform the manipulations.)
url = get_db_url("employees")
sql = '''
SELECT title, emp_no, dept_name
FROM dept_emp
JOIN titles USING(emp_no)
JOIN departments USING(dept_no)
'''
departments_titles = pd.read_sql(sql, url)
departments_titles
# Out:
#                title  emp_no         dept_name
# 0              Staff   10011  Customer Service
# 1       Senior Staff   10038  Customer Service
# 2              Staff   10038  Customer Service
# 3       Senior Staff   10049  Customer Service
# 4              Staff   10049  Customer Service
# ...              ...     ...               ...
# 489898  Senior Staff  499986             Sales
# 489899         Staff  499986             Sales
# 489900         Staff  499987             Sales
# 489901  Senior Staff  499988             Sales
# 489902         Staff  499988             Sales
#
# [489903 rows x 3 columns]

# %%
pd.crosstab(departments_titles.title, departments_titles.dept_name, margins=True)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
# All                            35075       125586    26070            26618
#
# dept_name           Marketing  Production  Quality Management  Research  \
# title
# Assistant Engineer          0        6445                1831       378
# Engineer                    0       49649               13852      2986
# ...

# %%
pd.crosstab(departments_titles.title, departments_titles.dept_name, margins=True).T
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
# All                              16721    126984       24           107992
#
# title               Senior Staff   Staff  Technique Leader     All
# dept_name
# ...
