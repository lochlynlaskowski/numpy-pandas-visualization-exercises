# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

from env import get_db_url
import pandas as pd


url = get_db_url("mall_customers")

# %%
sql = '''
SELECT * FROM customers
'''
mall_customers = pd.read_sql(sql, url)
mall_customers
# Out:
#      customer_id  gender  age  annual_income  spending_score
# 0              1    Male   19             15              39
# 1              2    Male   21             15              81
# 2              3  Female   20             16               6
# 3              4  Female   23             16              77
# 4              5  Female   31             17              40
# ..           ...     ...  ...            ...             ...
# 195          196  Female   35            120              79
# 196          197  Female   45            126              28
# 197          198    Male   32            126              74
# 198          199    Male   32            137              18
# 199          200    Male   30            137              83
#
# [200 rows x 5 columns]

# %%
sns.boxplot(data = mall_customers, x = 'age', y = 'annual_income')
# Out:
# <AxesSubplot:xlabel='age', ylabel='annual_income'>

# %%
mall_customers.age.max(), mall_customers.age.min()
# Out:
# (70, 18)

# %%
mall_customers['age_group'] = pd.cut(mall_customers.age, [10,20,30,40,50,60,70])
mall_customers
# Out:
#      customer_id  gender  age  annual_income  spending_score age_group
# 0              1    Male   19             15              39  (10, 20]
# 1              2    Male   21             15              81  (20, 30]
# 2              3  Female   20             16               6  (10, 20]
# 3              4  Female   23             16              77  (20, 30]
# 4              5  Female   31             17              40  (30, 40]
# ..           ...     ...  ...            ...             ...       ...
# 195          196  Female   35            120              79  (30, 40]
# 196          197  Female   45            126              28  (40, 50]
# 197          198    Male   32            126              74  (30, 40]
# 198          199    Male   32            137              18  (30, 40]
# 199          200    Male   30            137              83  (20, 30]
#
# [200 rows x 6 columns]

# %%
sns.boxplot(data = mall_customers, x = 'age_group', y = 'annual_income')
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='annual_income'>

# %%
sns.boxplot(data = mall_customers, x = 'age_group', y = 'annual_income', hue = 'gender')
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='annual_income'>

# %%
sns.violinplot(data = mall_customers, x = 'age_group', y = 'annual_income', hue = 'gender', color = 'green')
# Out:
# <AxesSubplot:xlabel='age_group', ylabel='annual_income'>

# %%
sns.relplot(data = mall_customers, x = 'spending_score', y = 'age', hue = 'gender')

# %%
sns.lmplot(data = mall_customers, x = 'spending_score', y = 'age', hue = 'gender')
